# %% [markdown]
# # Iris Dataset Analysis

# %% [markdown]
# # Import Modules

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Dataset

# %%
# Importing the dataset
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Removing the unnecessary id column
df = df.drop(columns = ['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# View the Basis stats of the Dataset
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
#Info about the Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Display the no. of samples under each class
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Preprocess the Dataset

# %%
#Check for null values
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
#For histogram of Sepal Length
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
#For histogram of Sepal Width
df['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
#For histogram of Petal Length
df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
#For histogram of Petal Width
df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
# Scatter-Plot
colors = ['Red' , 'Orange', 'Blue']
species = df['Species'].unique()

# %%
#Scatter plot for sepals. 
#We can see one class is distinct but other two can't be
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c = colors[i], label = species[i])
plt.xlabel("Sepal Length (in CM)")
plt.ylabel("Sepal Width (in CM)")
plt.legend();

# %%
#Scatter plot for Petals. 
#We can see one class is distinct but this time very small overlapping is there.
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = colors[i], label = species[i])
plt.xlabel("Petal Length (in CM)")
plt.ylabel("Petal Width (in CM)")
plt.legend();

# %%
#Scatter plot for Sepal Length vs Petal Length. 
#We can see one class is distinct but other two can't be
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['PetalLengthCm'], c = colors[i], label = species[i])
plt.xlabel("Sepal Length (in CM)")
plt.ylabel("Petal Length (in CM)")
plt.legend();

# %%
#Scatter plot for Sepal Width vs Petal Width. 
#We can see one class is distinct but other two can't be
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], c = colors[i], label = species[i])
plt.xlabel("Sepal Width (in CM)")
plt.ylabel("Petal Width (in CM)")
plt.legend();

# %% [markdown]
# # Correlation Matrix
# The correlation matrix is the table which shows the correlation coefficients between the variables. Each cell in the table shows the correlation between the two variables. The value is in the range of -1 to 1. If two variables have high correlation, we can neglect one variable from those two.

# %%
# df.corr() --> This line didn't worked coz we need numeric values only for Corr()
df.corr(numeric_only=True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr = df.corr(numeric_only = True)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Label Encoder
# In machine learning, we usually deal with the dataset which contains multiple labels in one or more than one column. These labels can be in the form of words or numbers.Label encoding refers to converting the labels into the numeric values so as to convert it to the machine readable form.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
# Train - 70%
# Test - 30%

X = df.drop(columns= ['Species'])
Y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

# %%
#Logistic Regression -- dont confuse it with Regression, it is a classification model.
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#Traning the data
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Print Metrics to get the performance of Logistic Regression
print("Accuracy : " , model.score(x_test, y_test)*100,"%")
# Out:
# Accuracy :  97.77777777777777 %

# %%
#KNN - K-Nearest-Neighbor
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
#Training the model
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Print Metrics to get the performance of KNN
print("Accuracy : " , model.score(x_test, y_test)*100,"%")
# Out:
# Accuracy :  97.77777777777777 %

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
#Training the model
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Print Metrics to get the performance of Decision Tree
print("Accuracy : " , model.score(x_test, y_test)*100,"%")
# Out:
# Accuracy :  93.33333333333333 %
